# %%
from langgraph.graph import  StateGraph, START, END
from typing import TypedDict

# %%
class BatsmanState(TypedDict):

    runs: int
    balls: int
    fours: int
    sixes: int

    sr: float
    bpb: float
    boundary_percent: float
    summary: str

# %%
def calculate_sr(state: BatsmanState):

    sr = (state['runs']/state['balls'])*100
    
    return {'sr': sr}

# %%
def calculate_bpb(state: BatsmanState):

    bpb = state['balls']/(state['fours'] + state['sixes'])

    return {'bpb': bpb}

# %%
def calculate_boundary_percent(state: BatsmanState):

    boundary_percent = (((state['fours'] * 4) + (state['sixes'] * 6))/state['runs'])*100

    return {'boundary_percent': boundary_percent}

# %%
def get_summary(state: BatsmanState):

    summary = f"""
Strike Rate - {state['sr']} \n
Balls per boundary - {state['bpb']} \n
Boundary percent - {state['boundary_percent']}
"""
    
    return {'summary': summary}

# %%
graph = StateGraph(BatsmanState)

graph.add_node('calculate_sr', calculate_sr)
graph.add_node('calculate_bpb', calculate_bpb)
graph.add_node('calculate_boundary_percent', calculate_boundary_percent)
graph.add_node('get_summary', get_summary)

# edges
graph.set_entry_point(START)
graph.add_edge(START, 'calculate_sr')
graph.add_edge('calculate_sr', 'calculate_bpb')
graph.add_edge('calculate_bpb', 'calculate_boundary_percent')
graph.add_edge('calculate_boundary_percent', 'get_summary')

graph.add_edge('get_summary', END)

workflow = graph.compile()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 9
#       6 graph.add_node('get_summary', get_summary)
#       8 # edges
# ----> 9 graph.set_entry_point(START)
#      10 graph.add_edge(START, 'calculate_sr')
#      11 graph.add_edge(START, 'calculate_bpb')
#
# File ~/miniconda3/envs/llm/lib/python3.10/site-packages/langgraph/graph/graph.py:276, in Graph.set_entry_point(self, key)
#     265 def set_entry_point(self, key: str) -> None:
#     266     """Specifies the first node to be called in the graph.
#     267
#     268     Equivalent to calling `add_edge(START, key)`.
#    (...)
#     274         None
#     275     """
# --> 276     return self.add_edge(START, key)
#
# File ~/miniconda3/envs/llm/lib/python3.10/site-packages/langgraph/graph/state.py:355, in StateGraph.add_edge(self, start_key, end_key)
#     340 """Adds a directed edge from the start node to the end node.
#     341
#     342 If the graph transitions to the start_key node, it will always transition to the end_key node next.
#    (...)
#     352     None
#     353 """
#     354 if isinstance(start_key, str):
# --> 355     return super().add_edge(start_key, end_key)
#     357 if self.compiled:
#     358     logger.warning(
#     359         "Adding an edge to a graph that has already been compiled. This will "
#     360         "not be reflected in the compiled graph."
#     361     )
#
# File ~/miniconda3/envs/llm/lib/python3.10/site-packages/langgraph/graph/graph.py:194, in Graph.add_edge(self, start_key, end_key)
#     192     raise ValueError("END cannot be a start node")
#     193 if end_key == START:
# --> 194     raise ValueError("START cannot be an end node")
#     195 if not self.support_multiple_edges and start_key in set(
#     196     start for start, _ in self.edges
#     197 ):
#     198     raise ValueError(
#     199         f"Already found path for node '{start_key}'.\n"
#     200         "For multiple edges, use StateGraph with an annotated state key."
#     201     )
#
# ValueError: START cannot be an end node
