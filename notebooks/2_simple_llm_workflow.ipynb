# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
# define the state

class LLMState(TypedDict):
    question : str
    answer: str

# %%
def llm_qa(state: LLMState):
    question = state['question']

    prompt = f'answer the following question {question}'

    answer = model.invoke(prompt).content

    state['answer'] = answer

    return state

# %%
# define the graph
graph = StateGraph(LLMState)

# add node
graph.add_node('llm_qa', llm_qa)

# add edge
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile the graph
workflow = graph.compile()

# run the graph
initial_state = {'question' :'how for is the  moon away from the earth'}

final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# The average distance from the moon to the Earth is about 238,855 miles (384,400 kilometers).

# %%
# # visualizatio  of the graph
# from IPython.display import Image

# Image(
#     workflow.get_graph().draw_mermaid_png()
# )

# %%
initial_state = {'question': 'How far is moon from the earth'}

final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# The moon is approximately 384,400 miles (638,800 kilometers) away from Earth.
